# %%
import pandas as pd

# %%
#pip install openpyxl

# %%
stats = pd.read_excel(r'D:\data science\python\pandas\data.xlsx')

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
len(stats)
# Out:
# 195

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
len(stats.columns)
# Out:
# 5

# %%
stats.shape
# Out:
# (195, 5)

# %%
stats.isnull()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
stats.isna()
# Out:
#      CountryName  CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0          False        False      False          False        False
# 1          False        False      False          False        False
# 2          False        False      False          False        False
# 3          False        False      False          False        False
# 4          False        False      False          False        False
# ..           ...          ...        ...            ...          ...
# 190        False        False      False          False        False
# 191        False        False      False          False        False
# 192        False        False      False          False        False
# 193        False        False      False          False        False
# 194        False        False      False          False        False
#
# [195 rows x 5 columns]

# %%
stats.isnull().sum()
# Out:
# CountryName      0
# CountryCode      0
# BirthRate        0
# InternetUsers    0
# IncomeGroup      0
# dtype: int64

# %%
stats.dtypes
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %%
stats.types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6956\3670038302.py in ?()
# ----> 1 stats.types
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %%
stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    195 non-null    object
#  1   CountryCode    195 non-null    object
#  2   BirthRate      195 non-null    float64
#  3   InternetUsers  195 non-null    float64
#  4   IncomeGroup    195 non-null    object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
type(stats)
# Out:
# pandas.core.frame.DataFrame

# %%
stats.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats.tail()
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
stats.head(2)
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0        Aruba         ABW     10.244           78.9  High income
# 1  Afghanistan         AFG     35.253            5.9   Low income

# %%
stats.head(10)
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244        78.9000
# 1           Afghanistan         AFG     35.253         5.9000
# 2                Angola         AGO     45.985        19.1000
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
stats.head(50)
# Out:
#                  CountryName CountryCode  BirthRate  InternetUsers  \
# 0                      Aruba         ABW     10.244       78.90000
# 1                Afghanistan         AFG     35.253        5.90000
# 2                     Angola         AGO     45.985       19.10000
# 3                    Albania         ALB     12.877       57.20000
# 4       United Arab Emirates         ARE     11.044       88.00000
# 5                  Argentina         ARG     17.716       59.90000
# 6                    Armenia         ARM     13.308       41.90000
# 7        Antigua and Barbuda         ATG     16.447       63.40000
# 8                  Australia         AUS     13.200       83.00000
# 9                    Austria         AUT      9.400       80.61880
# 10                Azerbaijan         AZE     18.300       58.70000
# 11                   Burundi         BDI     44.151        1.30000
# 12                   Belgium         BEL     11.200       82.17020
# ...

# %%
stats.head(150)
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244        78.9000
# 1             Afghanistan         AFG     35.253         5.9000
# 2                  Angola         AGO     45.985        19.1000
# 3                 Albania         ALB     12.877        57.2000
# 4    United Arab Emirates         ARE     11.044        88.0000
# ..                    ...         ...        ...            ...
# 145                 Qatar         QAT     11.940        85.3000
# 146               Romania         ROU      8.800        49.7645
# 147    Russian Federation         RUS     13.200        67.9700
# 148                Rwanda         RWA     32.689         9.0000
# 149          Saudi Arabia         SAU     20.576        60.5000
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats.tail(2)
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 193      Zambia         ZMB     40.471           15.4  Lower middle income
# 194    Zimbabwe         ZWE     35.715           18.5           Low income

# %%
stats.tail(20)
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 175                         Tunisia         TUN     19.800          43.80
# 176                          Turkey         TUR     16.836          46.25
# 177                        Tanzania         TZA     39.518           4.40
# 178                          Uganda         UGA     43.474          16.20
# 179                         Ukraine         UKR     11.100          41.00
# 180                         Uruguay         URY     14.374          57.69
# 181                   United States         USA     12.500          84.20
# 182                      Uzbekistan         UZB     22.500          38.20
# 183  St. Vincent and the Grenadines         VCT     16.306          52.00
# 184                   Venezuela, RB         VEN     19.842          54.90
# 185           Virgin Islands (U.S.)         VIR     10.700          45.30
# 186                         Vietnam         VNM     15.537          43.90
# ...

# %%
stats.tail(15)
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 180                         Uruguay         URY     14.374          57.69
# 181                   United States         USA     12.500          84.20
# 182                      Uzbekistan         UZB     22.500          38.20
# 183  St. Vincent and the Grenadines         VCT     16.306          52.00
# 184                   Venezuela, RB         VEN     19.842          54.90
# 185           Virgin Islands (U.S.)         VIR     10.700          45.30
# 186                         Vietnam         VNM     15.537          43.90
# 187                         Vanuatu         VUT     26.739          11.30
# 188              West Bank and Gaza         PSE     30.394          46.60
# 189                           Samoa         WSM     26.172          15.30
# 190                     Yemen, Rep.         YEM     32.947          20.00
# 191                    South Africa         ZAF     20.850          46.50
# ...

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats['CountryName']
# Out:
# 0                     Aruba
# 1               Afghanistan
# 2                    Angola
# 3                   Albania
# 4      United Arab Emirates
#                ...
# 190             Yemen, Rep.
# 191            South Africa
# 192        Congo, Dem. Rep.
# 193                  Zambia
# 194                Zimbabwe
# Name: CountryName, Length: 195, dtype: object

# %%
stats['BirthRate']
# Out:
# 0      10.244
# 1      35.253
# 2      45.985
# 3      12.877
# 4      11.044
#         ...
# 190    32.947
# 191    20.850
# 192    42.394
# 193    40.471
# 194    35.715
# Name: BirthRate, Length: 195, dtype: float64

# %%
stats[['BirthRate', 'InternetUsers']]
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %% [markdown]
# # lets split the dataset to nmerical & categorical a

# %%
stats.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
stats_numeric_data = stats[['BirthRate', 'InternetUsers']]

# %%
stats_numeric_data
# Out:
#      BirthRate  InternetUsers
# 0       10.244           78.9
# 1       35.253            5.9
# 2       45.985           19.1
# 3       12.877           57.2
# 4       11.044           88.0
# ..         ...            ...
# 190     32.947           20.0
# 191     20.850           46.5
# 192     42.394            2.2
# 193     40.471           15.4
# 194     35.715           18.5
#
# [195 rows x 2 columns]

# %%
stats_numeric_data = stats[['BirthRate', 'InternetUsers']]

# %%
stats_numeric_data.head()
# Out:
#    BirthRate  InternetUsers
# 0     10.244           78.9
# 1     35.253            5.9
# 2     45.985           19.1
# 3     12.877           57.2
# 4     11.044           88.0

# %%
stats_numeric_data.head(2)
# Out:
#    BirthRate  InternetUsers
# 0     10.244           78.9
# 1     35.253            5.9

# %%
stats_numeric_data.head(10)
# Out:
#    BirthRate  InternetUsers
# 0     10.244        78.9000
# 1     35.253         5.9000
# 2     45.985        19.1000
# 3     12.877        57.2000
# 4     11.044        88.0000
# 5     17.716        59.9000
# 6     13.308        41.9000
# 7     16.447        63.4000
# 8     13.200        83.0000
# 9      9.400        80.6188

# %%
stats_categorical_data = stats[['CountryName', 'CountryCode', 'IncomeGroup']]

# %%
stats_categorical_data
# Out:
#               CountryName CountryCode          IncomeGroup
# 0                   Aruba         ABW          High income
# 1             Afghanistan         AFG           Low income
# 2                  Angola         AGO  Upper middle income
# 3                 Albania         ALB  Upper middle income
# 4    United Arab Emirates         ARE          High income
# ..                    ...         ...                  ...
# 190           Yemen, Rep.         YEM  Lower middle income
# 191          South Africa         ZAF  Upper middle income
# 192      Congo, Dem. Rep.         COD           Low income
# 193                Zambia         ZMB  Lower middle income
# 194              Zimbabwe         ZWE           Low income
#
# [195 rows x 3 columns]

# %%
stats_categorical_data.head(2)
# Out:
#    CountryName CountryCode  IncomeGroup
# 0        Aruba         ABW  High income
# 1  Afghanistan         AFG   Low income

# %%
stats_categorical_data.tail(2)
# Out:
#     CountryName CountryCode          IncomeGroup
# 193      Zambia         ZMB  Lower middle income
# 194    Zimbabwe         ZWE           Low income

# %%
print(stats.shape)
print(stats_numeric_data.shape)
print(stats_categorical_data.shape)
# Out:
# (195, 5)
# (195, 2)
# (195, 3)

# %% [markdown]
# # Slicing in pandas

# %%
stats[:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats[:3]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0        Aruba         ABW     10.244           78.9          High income
# 1  Afghanistan         AFG     35.253            5.9           Low income
# 2       Angola         AGO     45.985           19.1  Upper middle income

# %%
stats[3:]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# 5               Argentina         ARG     17.716           59.9
# 6                 Armenia         ARM     13.308           41.9
# 7     Antigua and Barbuda         ATG     16.447           63.4
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 3    Upper middle income
# 4            High income
# 5            High income
# 6    Lower middle income
# 7            High income
# ..                   ...
# ...

# %%
stats[:5]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
stats[150:]
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 150                           Sudan         SDN     33.477        22.7000
# 151                         Senegal         SEN     38.533        13.1000
# 152                       Singapore         SGP      9.300        81.0000
# 153                 Solomon Islands         SLB     30.578         8.0000
# 154                    Sierra Leone         SLE     36.729         1.7000
# 155                     El Salvador         SLV     17.476        23.1093
# 156                         Somalia         SOM     43.891         1.5000
# 157                          Serbia         SRB      9.200        51.5000
# 158                     South Sudan         SSD     37.126        14.1000
# 159           Sao Tome and Principe         STP     34.537        23.0000
# 160                        Suriname         SUR     18.455        37.4000
# 161                 Slovak Republic         SVK     10.100        77.8826
# ...

# %%
stats[3:10]
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 3               Albania         ALB     12.877        57.2000
# 4  United Arab Emirates         ARE     11.044        88.0000
# 5             Argentina         ARG     17.716        59.9000
# 6               Armenia         ARM     13.308        41.9000
# 7   Antigua and Barbuda         ATG     16.447        63.4000
# 8             Australia         AUS     13.200        83.0000
# 9               Austria         AUT      9.400        80.6188
#
#            IncomeGroup
# 3  Upper middle income
# 4          High income
# 5          High income
# 6  Lower middle income
# 7          High income
# 8          High income
# 9          High income

# %%
stats[19:59]
# Out:
#                  CountryName CountryCode  BirthRate  InternetUsers  \
# 19    Bosnia and Herzegovina         BIH      9.062      57.790000
# 20                   Belarus         BLR     12.500      54.170000
# 21                    Belize         BLZ     23.092      33.600000
# 22                   Bermuda         BMU     10.400      95.300000
# 23                   Bolivia         BOL     24.236      36.940000
# 24                    Brazil         BRA     14.931      51.040000
# 25                  Barbados         BRB     12.188      73.000000
# 26         Brunei Darussalam         BRN     16.405      64.500000
# 27                    Bhutan         BTN     18.134      29.900000
# 28                  Botswana         BWA     25.267      15.000000
# 29  Central African Republic         CAF     34.076       3.500000
# 30                    Canada         CAN     10.900      85.800000
# 31               Switzerland         CHE     10.200      86.340000
# ...

# %%
stats[3:50:5]
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 3              Albania         ALB     12.877        57.2000
# 8            Australia         AUS     13.200        83.0000
# 13               Benin         BEN     36.440         4.9000
# 18        Bahamas, The         BHS     15.339        72.0000
# 23             Bolivia         BOL     24.236        36.9400
# 28            Botswana         BWA     25.267        15.0000
# 33               China         CHN     12.100        45.8000
# 38             Comoros         COM     34.326         6.5000
# 43              Cyprus         CYP     11.436        65.4548
# 48  Dominican Republic         DOM     21.198        45.9000
#
#             IncomeGroup
# 3   Upper middle income
# 8           High income
# 13           Low income
# 18          High income
# 23  Lower middle income
# 28  Upper middle income
# 33  Upper middle income
# 38           Low income
# 43          High income
# 48  Upper middle income

# %%
stats[6:150:10]
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  \
# 6              Armenia         ARM     13.308        41.9000
# 16            Bulgaria         BGR      9.200        53.0615
# 26   Brunei Darussalam         BRN     16.405        64.5000
# 36         Congo, Rep.         COG     37.011         6.6000
# 46            Djibouti         DJI     25.486         9.5000
# 56             Finland         FIN     10.700        91.5144
# 66       Guinea-Bissau         GNB     37.503         3.1000
# 76             Croatia         HRV      9.400        66.7476
# 86               Italy         ITA      8.500        58.4593
# 96              Kuwait         KWT     20.575        75.4600
# 106         Luxembourg         LUX     11.300        93.7765
# 116              Malta         MLT      9.500        68.9138
# 126      New Caledonia         NCL     17.000        66.0000
# 136             Panama         PAN     19.680        44.0300
# ...

# %%
stats[20:195:10]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# 110      Moldova         MDA     12.141      45.000000  Lower middle income
# 120   Mozambique         MOZ     39.705       5.400000           Low income
# ...

# %%
stats[::2]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 2                  Angola         AGO     45.985           19.1
# 4    United Arab Emirates         ARE     11.044           88.0
# 6                 Armenia         ARM     13.308           41.9
# 8               Australia         AUS     13.200           83.0
# ..                    ...         ...        ...            ...
# 186               Vietnam         VNM     15.537           43.9
# 188    West Bank and Gaza         PSE     30.394           46.6
# 190           Yemen, Rep.         YEM     32.947           20.0
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 2    Upper middle income
# 4            High income
# 6    Lower middle income
# 8            High income
# ..                   ...
# ...

# %%
stats[::10]
# Out:
#      CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 0          Aruba         ABW     10.244      78.900000          High income
# 10    Azerbaijan         AZE     18.300      58.700000  Upper middle income
# 20       Belarus         BLR     12.500      54.170000  Upper middle income
# 30        Canada         CAN     10.900      85.800000          High income
# 40    Costa Rica         CRI     15.022      45.960000  Upper middle income
# 50       Ecuador         ECU     21.070      40.353684  Upper middle income
# 60         Gabon         GAB     30.555       9.200000  Upper middle income
# 70     Greenland         GRL     14.500      65.800000          High income
# 80         India         IND     20.291      15.100000  Lower middle income
# 90    Kazakhstan         KAZ     22.730      54.000000  Upper middle income
# 100        Libya         LBY     21.425      16.500000  Upper middle income
# ...

# %%
stats[::-2]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715           18.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 190           Yemen, Rep.         YEM     32.947           20.0
# 188    West Bank and Gaza         PSE     30.394           46.6
# 186               Vietnam         VNM     15.537           43.9
# ..                    ...         ...        ...            ...
# 8               Australia         AUS     13.200           83.0
# 6                 Armenia         ARM     13.308           41.9
# 4    United Arab Emirates         ARE     11.044           88.0
# 2                  Angola         AGO     45.985           19.1
# 0                   Aruba         ABW     10.244           78.9
#
#              IncomeGroup
# 194           Low income
# 192           Low income
# 190  Lower middle income
# 188  Lower middle income
# 186  Lower middle income
# ..                   ...
# ...

# %%
stats[::-20]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 194              Zimbabwe         ZWE     35.715          18.50
# 174   Trinidad and Tobago         TTO     14.590          63.80
# 154          Sierra Leone         SLE     36.729           1.70
# 134                  Oman         OMN     20.419          66.45
# 114        Macedonia, FYR         MKD     11.222          65.24
# 94               Kiribati         KIR     29.044          11.50
# 74   Hong Kong SAR, China         HKG      7.900          74.20
# 54                Estonia         EST     10.300          79.40
# 34          Cote d'Ivoire         CIV     37.320           8.40
# 14           Burkina Faso         BFA     40.551           9.10
#
#              IncomeGroup
# 194           Low income
# 174          High income
# 154           Low income
# 134          High income
# 114  Upper middle income
# 94   Lower middle income
# 74           High income
# 54           High income
# ...

# %%
stats
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...

# %%
stats[0:200]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  \
# 0                   Aruba         ABW     10.244           78.9
# 1             Afghanistan         AFG     35.253            5.9
# 2                  Angola         AGO     45.985           19.1
# 3                 Albania         ALB     12.877           57.2
# 4    United Arab Emirates         ARE     11.044           88.0
# ..                    ...         ...        ...            ...
# 190           Yemen, Rep.         YEM     32.947           20.0
# 191          South Africa         ZAF     20.850           46.5
# 192      Congo, Dem. Rep.         COD     42.394            2.2
# 193                Zambia         ZMB     40.471           15.4
# 194              Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 0            High income
# 1             Low income
# 2    Upper middle income
# 3    Upper middle income
# 4            High income
# ..                   ...
# ...
