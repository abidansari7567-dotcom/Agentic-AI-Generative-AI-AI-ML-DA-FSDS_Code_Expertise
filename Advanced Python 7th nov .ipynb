# %%
if True:
    print('Data Science')
# Out:
# Data Science

# %%
if False:
    print('Data Science')
print('bye for now')
# Out:
# bye for now

# %%
if True:
    print('Data Science')
print('bye for now')
# Out:
# Data Science
# bye for now

# %%
if True:
    print('Data Science')
else:
    print('bye for now')
# Out:
# Data Science

# %%
if False:
    print('Data Science job')
else:
    print('no job')
# Out:
# no job

# %%
x = 4
r = x % 2

if r == 0:
     print('Even number')
# Out:
# Even number

# %%
x = 5
r = x % 2

if r == 0:
    print('Even number')

# %%
x = 5
r = x % 2

if r != 0:
    print('odd number')
# Out:
# odd number

# %%
x = 7
r = x % 2

if r == 1:
    print('odd number')
# Out:
# odd number

# %%
x = 5
r = x % 2

if r == 0:
    print('Even number')

print('odd number')
# Out:
# odd number

# %%
x = 4
r = x % 2

if r == 0:
    print('Even number')
print('odd number')
# Out:
# Even number
# odd number

# %%
x = 9
r = x % 2

if r == 0:
    print('Even number')

else:
    print('odd number')
# Out:
# odd number

# %%
x = 8
r = x % 2
if r == 0:
    print('Even number')

else:
    print('odd number')
# Out:
# Even number

# %%
x = 9
r = x % 2

if r != 0:
    print('odd number')
else:
    print('Even number')
# Out:
# odd number

# %%
x = 3
r = x % 2

if r == 0:
    print('Even number')
    if x>5:
        print('greater number')

    else:
        print('Odd Number')

# %%
x = 4
r = x % 2

if r == 0:
    print('Even Number')

    if x>5:
        print('greater number')

    else:
        print('Odd Number')
# Out:
# Even Number
# Odd Number

# %%
x = 4
r = x % 2

if r == 0:
    print('Even number')

    if x>5:
        print('greater number')
    else:
        print('lesser number')

else:
    print('Odd Number')
# Out:
# Even number
# lesser number

# %%
x = 13
r = x % 2

if r == 0:
    print('Even number')

    if x>5:
        print('greater number')
    else:
        print('lesser number')

else:
    print('Odd Number')
# Out:
# Odd Number

# %%
x = 3

if x == 1:
    print('one')
if x == 2:
    print('Two')
if x == 3:
    print('Three')
if x == 4:
    print('Four')
# Out:
# Three

# %%
x = 1

if x == 1:
    print('one')
elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('Four')
# Out:
# one

# %%
x = 5

if x == 1:
    print('one')
elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('Four')

else:
    print('number not found')
# Out:
# number not found

# %%
age = 20
if age > 18: print('Eligible to Vote.')
# Out:
# Eligible to Vote.
