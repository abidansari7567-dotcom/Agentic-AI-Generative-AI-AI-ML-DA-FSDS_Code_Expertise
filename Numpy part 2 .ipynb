# %% [markdown]
# # Operations

# %%
import numpy as np

# %%
my_list = [0,1,2,3,4,5]
my_list
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
arr = np.array(my_list)

# %%
arr
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
a = np.random.randint(10,20,10)

# %%
a
# Out:
# array([16, 14, 11, 13, 15, 16, 13, 10, 15, 13], dtype=int32)

# %%
id(a)
# Out:
# 2042842623760

# %%
arr
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
arr2 =np.random.randint(0,100,(10,10))

# %%
arr2
# Out:
# array([[ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [ 2, 64, 32, 10, 96, 88, 78, 52, 40, 62],
#        [21, 41, 60, 44, 74, 25, 12, 81, 86, 56],
#        [42, 18, 51, 80, 46,  8,  2, 88, 30, 39],
#        [68, 51, 73, 73, 87, 12, 27, 17, 16, 49],
#        [41,  6, 99,  0, 86, 78, 39, 61, 84, 64],
#        [71, 95, 85,  2, 56, 78, 48, 89, 11, 54]], dtype=int32)

# %%
arr3 = np.random.randint(1,50,(5,5))

# %%
arr3
# Out:
# array([[ 3, 10, 17,  1, 22],
#        [ 6, 38, 19, 23, 38],
#        [29, 38, 28,  9, 46],
#        [20, 32, 18, 36, 40],
#        [18, 26, 29,  8,  5]], dtype=int32)

# %% [raw]
# arr

# %%
arr[:]
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
arr
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
arr[:4]
# Out:
# array([0, 1, 2, 3])

# %%
arr[:2]
# Out:
# array([0, 1])

# %%
arr[:5]
# Out:
# array([0, 1, 2, 3, 4])

# %%
arr[:3]
# Out:
# array([0, 1, 2])

# %%
arr2[:]
# Out:
# array([[ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [ 2, 64, 32, 10, 96, 88, 78, 52, 40, 62],
#        [21, 41, 60, 44, 74, 25, 12, 81, 86, 56],
#        [42, 18, 51, 80, 46,  8,  2, 88, 30, 39],
#        [68, 51, 73, 73, 87, 12, 27, 17, 16, 49],
#        [41,  6, 99,  0, 86, 78, 39, 61, 84, 64],
#        [71, 95, 85,  2, 56, 78, 48, 89, 11, 54]], dtype=int32)

# %%
arr2[0:5]
# Out:
# array([[ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [ 2, 64, 32, 10, 96, 88, 78, 52, 40, 62]], dtype=int32)

# %%
arr2
# Out:
# array([[ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [ 2, 64, 32, 10, 96, 88, 78, 52, 40, 62],
#        [21, 41, 60, 44, 74, 25, 12, 81, 86, 56],
#        [42, 18, 51, 80, 46,  8,  2, 88, 30, 39],
#        [68, 51, 73, 73, 87, 12, 27, 17, 16, 49],
#        [41,  6, 99,  0, 86, 78, 39, 61, 84, 64],
#        [71, 95, 85,  2, 56, 78, 48, 89, 11, 54]], dtype=int32)

# %%
arr2[1,4]
# Out:
# np.int32(89)

# %%
arr2
# Out:
# array([[ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [ 2, 64, 32, 10, 96, 88, 78, 52, 40, 62],
#        [21, 41, 60, 44, 74, 25, 12, 81, 86, 56],
#        [42, 18, 51, 80, 46,  8,  2, 88, 30, 39],
#        [68, 51, 73, 73, 87, 12, 27, 17, 16, 49],
#        [41,  6, 99,  0, 86, 78, 39, 61, 84, 64],
#        [71, 95, 85,  2, 56, 78, 48, 89, 11, 54]], dtype=int32)

# %%
arr2[-5,5]
# Out:
# np.int32(25)

# %%
arr2[-5,-5]
# Out:
# np.int32(25)

# %%
arr2[5,-6]
# Out:
# np.int32(74)

# %%
arr2[-8,6]
# Out:
# np.int32(70)

# %%
arr2[-1,-9]
# Out:
# np.int32(95)

# %%
arr2
# Out:
# array([[ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [ 2, 64, 32, 10, 96, 88, 78, 52, 40, 62],
#        [21, 41, 60, 44, 74, 25, 12, 81, 86, 56],
#        [42, 18, 51, 80, 46,  8,  2, 88, 30, 39],
#        [68, 51, 73, 73, 87, 12, 27, 17, 16, 49],
#        [41,  6, 99,  0, 86, 78, 39, 61, 84, 64],
#        [71, 95, 85,  2, 56, 78, 48, 89, 11, 54]], dtype=int32)

# %%
arr2[-1,-2]
# Out:
# np.int32(11)

# %%
arr2
# Out:
# array([[ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [ 2, 64, 32, 10, 96, 88, 78, 52, 40, 62],
#        [21, 41, 60, 44, 74, 25, 12, 81, 86, 56],
#        [42, 18, 51, 80, 46,  8,  2, 88, 30, 39],
#        [68, 51, 73, 73, 87, 12, 27, 17, 16, 49],
#        [41,  6, 99,  0, 86, 78, 39, 61, 84, 64],
#        [71, 95, 85,  2, 56, 78, 48, 89, 11, 54]], dtype=int32)

# %%
arr2[::-1]
# Out:
# array([[71, 95, 85,  2, 56, 78, 48, 89, 11, 54],
#        [41,  6, 99,  0, 86, 78, 39, 61, 84, 64],
#        [68, 51, 73, 73, 87, 12, 27, 17, 16, 49],
#        [42, 18, 51, 80, 46,  8,  2, 88, 30, 39],
#        [21, 41, 60, 44, 74, 25, 12, 81, 86, 56],
#        [ 2, 64, 32, 10, 96, 88, 78, 52, 40, 62],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57]], dtype=int32)

# %%
arr2[::-3]
# Out:
# array([[71, 95, 85,  2, 56, 78, 48, 89, 11, 54],
#        [42, 18, 51, 80, 46,  8,  2, 88, 30, 39],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57]], dtype=int32)

# %%
arr2
# Out:
# array([[ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [ 2, 64, 32, 10, 96, 88, 78, 52, 40, 62],
#        [21, 41, 60, 44, 74, 25, 12, 81, 86, 56],
#        [42, 18, 51, 80, 46,  8,  2, 88, 30, 39],
#        [68, 51, 73, 73, 87, 12, 27, 17, 16, 49],
#        [41,  6, 99,  0, 86, 78, 39, 61, 84, 64],
#        [71, 95, 85,  2, 56, 78, 48, 89, 11, 54]], dtype=int32)

# %%
arr2[::-2]
# Out:
# array([[71, 95, 85,  2, 56, 78, 48, 89, 11, 54],
#        [68, 51, 73, 73, 87, 12, 27, 17, 16, 49],
#        [21, 41, 60, 44, 74, 25, 12, 81, 86, 56],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82]], dtype=int32)

# %%
arr2[::-4]
# Out:
# array([[71, 95, 85,  2, 56, 78, 48, 89, 11, 54],
#        [21, 41, 60, 44, 74, 25, 12, 81, 86, 56],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82]], dtype=int32)

# %%
arr2[:-3]
# Out:
# array([[ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [ 2, 64, 32, 10, 96, 88, 78, 52, 40, 62],
#        [21, 41, 60, 44, 74, 25, 12, 81, 86, 56],
#        [42, 18, 51, 80, 46,  8,  2, 88, 30, 39]], dtype=int32)

# %%
arr2
# Out:
# array([[ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [ 2, 64, 32, 10, 96, 88, 78, 52, 40, 62],
#        [21, 41, 60, 44, 74, 25, 12, 81, 86, 56],
#        [42, 18, 51, 80, 46,  8,  2, 88, 30, 39],
#        [68, 51, 73, 73, 87, 12, 27, 17, 16, 49],
#        [41,  6, 99,  0, 86, 78, 39, 61, 84, 64],
#        [71, 95, 85,  2, 56, 78, 48, 89, 11, 54]], dtype=int32)

# %%
arr2[:4]
# Out:
# array([[ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89]], dtype=int32)

# %%
arr2[:5]
# Out:
# array([[ 4, 99, 79, 79, 36, 32, 95,  2, 48, 57],
#        [68, 54, 82, 17, 89, 60, 51, 27, 11, 82],
#        [66,  6, 66,  4, 37, 99, 70, 12, 22, 58],
#        [62, 87, 58, 46, 93, 51, 79, 76, 23, 89],
#        [ 2, 64, 32, 10, 96, 88, 78, 52, 40, 62]], dtype=int32)

# %%
arr
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
arr.max()
# Out:
# np.int64(5)

# %%
arr.min()
# Out:
# np.int64(0)

# %%
arr.mean()
# Out:
# np.float64(2.5)

# %%
arr.median()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 arr.median()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
from numpy import *
a = array([1,2,3,4,5])
median(a)
# Out:
# np.float64(3.0)

# %%
from numpy import *
a1 = array([1,2,3,4,9])
median(a1)
# Out:
# np.float64(3.0)

# %%
from numpy import *
a1 = array([1,3,4,5,6,8,9])
median(a1)
# Out:
# np.float64(5.0)
