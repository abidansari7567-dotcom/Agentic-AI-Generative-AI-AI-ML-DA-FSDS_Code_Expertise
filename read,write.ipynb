# %%
import cv2

# %%
import numpy as np

# %%
input = cv2.imread(r"D:\data science\AI\Gen AI\class\9th. data Augumention\cat.jpg")

# %%
input
# Out:
# array([[[127, 121, 114],
#         [129, 124, 115],
#         [140, 131, 122],
#         ...,
#         [185, 170, 161],
#         [184, 167, 158],
#         [179, 162, 153]],
#
#        [[138, 132, 125],
#         [130, 125, 116],
#         [136, 127, 118],
#         ...,
#         [185, 170, 161],
#         [184, 167, 158],
#         [180, 163, 154]],
#
#        [[141, 135, 128],
#         [129, 124, 115],
#         [139, 130, 121],
#         ...,
#         [185, 170, 161],
#         [185, 168, 159],
#         [181, 164, 155]],
#
#        ...,
#
#        [[212, 203, 199],
#         [212, 203, 199],
#         [213, 204, 200],
#         ...,
#         [207, 204, 206],
#         [207, 204, 206],
#         [207, 204, 206]],
#
#        [[212, 203, 199],
#         [212, 203, 199],
#         [213, 204, 200],
#         ...,
#         [205, 202, 204],
#         [205, 202, 204],
#         [205, 202, 204]],
#
#        [[212, 203, 200],
#         [212, 203, 200],
#         [213, 204, 200],
#         ...,
#         [203, 200, 202],
#         [203, 200, 202],
#         [202, 199, 201]]], shape=(183, 275, 3), dtype=uint8)

# %%
cv2.imshow('input', input)
cv2.waitKey()
cv2.destroyWindows()

# %%
print('Height of Image:', int(input.shape[0]), 'pixels')
print('Weight of Image:', int(input.shape[1]), 'pixels')
# Out:
# Height of Image: 183 pixels
# Weight of Image: 275 pixels

# %%
cv2.imwrite('output.png', input)
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'd:\\data science\\AI\\Gen AI\\project\\OpenCv'
