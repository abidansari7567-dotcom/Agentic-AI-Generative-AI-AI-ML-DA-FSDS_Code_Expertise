# %%
pip install u langchain[google-gemini]
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: langchain 1.2.10 does not provide the extra 'google-gemini'

# %%
from langchain_core.messages import HumanMessage, SystemMessage
messages = [
    SystemMessage("Translate the following from english into hindi")
]

# %%
AIzaSyDt3eSK9CdtzvMcj43VYoj45N2A_FEmuOU
