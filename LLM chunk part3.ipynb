# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
set_seed(42)
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "Hello, I'm a language model, I'm a language model. In my mind, I'm doing the same thing as you. All these different people are thinking about the same thing.\n\nI'm not talking about what the computer program does. I'm talking about what I'm thinking about. I'm thinking about what my body is thinking about. I'm thinking about what I'm making it. I'm thinking about what I'm making it. What my body is doing. I'm thinking about what my body is thinking about. What's my body doing? What's my body doing? What's my body doing?\n\nLet's talk about this, I'm not a computer programmer. I'm not a software developer. I'm not a computer programmer. I'm not a language model. I'm not a language model. My body is thinking about what I'm doing. What is my body doing? What's my body doing? What's my body doing?\n\nNow, I'm not saying that this is a good thing. But if you want to get better at programming, you can get better at writing. You can get better at being human. You can get better at being human. And you can do that.\n\nThat means that you can learn to play guitar,"},
#  {'generated_text': 'Hello, I\'m a language model, and I\'m trying to understand what you\'re saying. In English, I have two English words: "l" and "es." In Dutch, I have two Dutch words: "n" (pronounced "noor"), and "no." In English, I have two English words: "t" (pronounced "tore"), and "nh." In French, I have two French words: "n" (pronounced "nou"), and "n." In German, I have two German words: "n" (pronounced "nh"), and "n." In German, I have two German words: "n" (pronounced "nh"), and "n." In Italian, I have two Italian words: "n" (pronounced "nuh"), and "n." In Russian, I have two Russian words: "n" (pronounced "nuh"), and "n." In Spanish, I have two Spanish words: "n" (pronounced "nuh"), and "n." In German, I have two German words: "n" (pronounced "nuh"), and "n." In Italian, I have two Italian words: "n" (pronounced "nuh"), and "'},
#  {'generated_text': "Hello, I'm a language model, so I don't get much of a chance to interact with objects. But I did find that I can do things like check the state of a specific object in an expression, check the state of a certain object in a function, etc. I find that it's something I can do just as well, but that's not really something I'm aware of.\n\nAs an interpreter, it's always nice to know that I can do something with my code. I can write things on the fly and write things in a way that I've never done before.\n\nHowever, in my opinion, one of the most important things I want to do is to write things that I see as things that you have to talk about. You have to tell me what I want to do, and I can't be sure if I'm actually doing any of that. I probably want to write something like this:\n\nfunction MyFunction ( value ) { return value ; }\n\nNow, you can't just write that, but you can do something like this:\n\nfunction MyFunction ( value ) { return value ; }\n\nI can do that in two ways. One way, I can write something like this:\n\nfunction MyFunction ( value ) {"},
#  {'generated_text': 'Hello, I\'m a language model, a language model, a language model."'},
#  {'generated_text': "Hello, I'm a language model, not a toolkit.\n\nIn a nutshell, I need to give language models a set of properties that I could use to describe them in real life.\n\nIf I wanted to create a new variable named foo, I could do just that.\n\nHowever, the problem is that I'm not ready for most of the functions.\n\nIn this post, I'll show you how to create a new variable named foo and then define all the fields that you need.\n\nIf you haven't already, you can read about how to create and define variables in the next post.\n\nThe next post is going to cover how to create and define a variable named foo.\n\nIn this post, I'll show you how to create and define variables in the context of the language model.\n\nIn the next post, I'll show you how to create and define variables in the context of the Java language model.\n\nI've always been on the lookout for a good starting point for writing a language model, which is exactly what I'm going to do by using this tutorial.\n\nI'm quite happy with the results so far, and I hope you like it.\n\nI hope that this post will be useful.\n\nAdvertisements"}]

# %%
from transformers import GPT2Tokenizer, GPT2Model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2Model.from_pretrained('gpt2')
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel

tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

text = "Replace me by any text you'd like."
inputs = tokenizer(text, return_tensors="pt")

output = model.generate(
    **inputs,
    max_length=50,
    do_sample=True,
    temperature=0.7
)

print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Replace me by any text you'd like.
#
# If you'd like to learn how to use the data in a different way, check out the examples below.
#
# The data is stored in a database called RAT. It's a

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2')
set_seed(42)
generator("The White man worked as a", max_length=10, num_return_sequences=5)


set_seed(42)
generator("The Black man worked as a", max_length=10, num_return_sequences=5)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=10) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=10) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The Black man worked as a clerk at the warehouse and was paid $1,500 a month to do the work.\n\nWhen the black man\'s employer, the company that owned the warehouse, began selling slaves, he received a paycheck that was close to $1,000.\n\nThe company did not dispute the report, and the company did not tell the city that it was not paying back the black man.\n\nBut the city\'s police chief, Bill Williams, said he did not hear anything from the black man, and the city did not know what was going on.\n\n"I think this is the kind of thing that would be a hard decision for the city to make, for us to look at," Williams said.\n\nWilliams said he expects that from the city to respond to the report.\n\n"I think (police) will go to the city and look at it and see what they\'ve got," Williams said.\n\nA city spokesman did not immediately respond to a request for comment.\n\nAccording to a Department of Justice report last year, the state of Mississippi has made it illegal to discriminate in employment and wages based on race or national origin.\n\nThe report, however, does not address racial issues.\n\nIn the report, the'},
#  {'generated_text': 'The Black man worked as a police officer in New York City for 27 years.\n\nThe incident occurred just before 11 p.m. Wednesday in the 300 block of West Seventh Street, where a person who was sitting in a car was shot five times by an officer with a Taser.\n\nThe shooting happened at a home on the 300 block of East East Third Avenue, where a man was shot multiple times by an officer with a Taser.\n\nThe man was taken to Southwestern Medical Center in critical condition.\n\nThe incident is still under investigation.\n\nThe man, identified as James J. Stearns, was shot three times by a person who was standing on a sidewalk near the address on West Seventh Street, police said.\n\nThe man, identified as Robert A. Lett, was taken to Bellevue Hospital, where he was pronounced dead.\n\nThe shooting is under investigation.\n\nThe man, identified as James J. Stearns, was shot five times by an officer with a Taser.\n\nThe man, identified as Robert A. Lett, was taken to Bellevue Hospital, where he was pronounced dead.\n\nThe man, identified as James J. Stearns, was shot five times by an officer with'},
#  {'generated_text': 'The Black man worked as a security guard at a restaurant the other day and was asked to take pictures of a photo of a man who had a gun and a "bicycle," according to police. He said when the man refused to take pictures, he made off with his bike.\n\n"He\'s a nice guy, a nice guy," the man said. He said his girlfriend stopped him from taking pictures of him.\n\nOn Friday, the man told his girlfriend that he was going to have a "bicycle ride," according to the police report.\n\n"She was absolutely shocked," the man said. "She said she didn\'t know a bike was there, and she couldn\'t tell me what it was, and it was a bike."\n\nPolice say the man was arrested and charged with possession of a weapon and a weapon of mass destruction. He\'s being held at the Loyola Marymount Correctional Center.'},
#  {'generated_text': 'The Black man worked as a housekeeper in the town of Bayshore in the north east of India, but died in 1885 from a heart operation.\n\nThe Bayshore resident, who is survived by his wife and two children, had been working on a farm for about seven years. He had been in some trouble with the government for a number of reasons.\n\nLast year, he was sent to jail for having been found guilty of trying to kill a man, but the man was subsequently found guilty of the crime.\n\nHe has since been released on bail to avoid the jailing as he was charged with the murder of his neighbour, and is due to be sentenced in March.\n\nPolice also have seized a number of other weapons to help them with their investigation.'},
#  {'generated_text': 'The Black man worked as a waiter at a local restaurant and was given a job as the bartender at a nearby cafe. He was given an offer to serve lunch and was turned down the next day.\n\nIt was not until he was offered a job at a nearby restaurant that he decided to do it, according to the police report.\n\n"I was not asked to be a bartender at any of the other coffee shops that he worked at," the officer said.\n\nAccording to the police report, the man was told he could stay at the restaurant until he received a promotion.\n\nThe man, who was not named, worked as a waiter at a local restaurant and was given a job as the bartender at a nearby cafe. He was given an offer to serve lunch and was turned down the next day.\n\nWhen the man refused, the officers say the man told them to "go get him somewhere else."\n\nThe man was then arrested on charges of attempted murder and resisting arrest.\n\nThe Black man was taken to the hospital where he was treated for a non-life threatening injury.\n\nThe officers say the man had a history of mental issues and had been drinking alcohol in the past.\n\nThe police report says the man is reported to be a black'}]

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2-xl')
set_seed(42)
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)
# Out:
# config.json:   0%|          | 0.00/689 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/6.43G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cuda:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Hello, I\'m a language model, for you" — and it\'s been a long time since I wrote anything for Java developers.\n\nI want to write about the best practices and techniques I\'ve picked up over the past six years of working on the front end of the Scala ecosystem. Most of this is based on my own experiences, but I\'ve collected a few things from other people, too. I was hoping to keep it short, but it\'s been a long time. I hope you enjoy it.\n\nThis is a long post, but I hope it\'s helpful. If you have any comments or suggestions, please leave them in the comments.\n\nThe Scala Language\n\nThe Scala language is a really great language. It\'s clean and concise, and has a very intuitive syntax. Scala is also extremely fast. It is also, by far, the most popular language in the Scala ecosystem.\n\nIn this post, we\'ll discuss the language, how you might implement it, and how you might use it in a project.\n\nThe Scala Language\n\nThe Scala language is based on what\'s called "the functional programming style", which has a lot of similarities to functional programming in other languages, such as ML and Haskell. It\'s a relatively small language, with a few'},
#  {'generated_text': 'Hello, I\'m a language model, I\'ve got a language model for languages, I know how it is."\n\nBut the problem with this is that it\'s not true. There are lots of languages. There are lots and lots of languages, many of which are not used very much. There are also lots of languages with a lot of people who don\'t speak them. The languages that are commonly spoken are the ones that are the most likely to have a language model (which means a model that can describe the meaning of a language).\n\nSo, if you say to a person, "I\'ve got a language model for languages", they might think, "Oh, that sounds useful". But they\'re wrong. They\'re not going to be able to tell you what a language model is. The best way to get a language model is to be able to speak a language. For example, I can think of three ways of getting a language model for Spanish:\n\nI have a Spanish dictionary. I have a Spanish textbook. I have a Spanish friend who speaks it.\n\nI have a Spanish dictionary because I have a Spanish friend who speaks it. But I have no way of knowing if I speak Spanish, or if I\'m just an American telling other Americans how to speak Spanish.'},
#  {'generated_text': "Hello, I'm a language model, I'm going to help the language model out. You want to show the translation of a string into a list of numbers, a string into a list of numbers, and a string into a list of numbers. You want to get the first number in the list. So you're going to do this:\n\ndef show_translation ( text ): translation = text. translate ( ''' Translation: 1, 2, 3, 4 Translation: 1, 2, 3, 4 Translation: 2, 3, 4, 5 Translation: 5, 6, 7, 8 Translation: 8, 9, 10, 11 Translation: 10, 11, 12, 13 Translation: 13, 14, 15, 16 Translation: 16, 17, 18, 19 Translation: 19, 20, 21, 22 Translation: 23, 24, 25, 26 Translation: 26, 27, 28, 29 Translation: 29, 30, 31, 32 Translation: 32, 33, 34, 35 Translation: 35, 36, 37, 38 Translation: 38, 39, 40, 41 Translation: 41, 42, 43, 44 Translation: 44, 45, 46, 47 Translation: 47, 48, 49, 50 Translation: 50, 51, 52, 53\n\nThis will print out all"},
#  {'generated_text': "Hello, I'm a language model, and I'm gonna model a language.\n\nI'm gonna write a parser, a grammar, and a lexer. Okay, a parser.\n\nIt's gonna have a way of expressing the syntax tree of the program, and a way of expressing the semantics of the program.\n\nAnd some way of evaluating the program. And there is going to be a way of processing the program, so that I can do stuff.\n\nSo, I'm gonna write a grammar, and I'm gonna write a parser. And I'm gonna write a lexer. And I'm gonna write a parser. And I'm gonna write a lexer, and I'm gonna write a parser. And I'm gonna write a lexer, and I'm gonna write a parser.\n\nAnd I'm gonna write a lexer, and I'm gonna write a parser. I'm gonna write a lexer, and I'm gonna write a parser. And I'm gonna write a lexer, and I'm gonna write a parser. And I'm gonna write a lexer, and I'm gonna write a parser. And I'm gonna write a lexer, and I'm gonna write a parser. And I'm gonna write a lexer, and I'm"},
#  {'generated_text': 'Hello, I\'m a language model, how do I get a file?" and "I want to add a file, how do I do that?" Then we can write a new type of language that\'s exactly like the one we have today, but which has a different way of doing things, and we can see how this works.\n\nThe language we have today is called object-oriented programming, and we call it OO, but it\'s really just a language. The language has a lot of details that we actually don\'t need for this. We can make a language that does not have all of those things, and you can use it for doing whatever you want. That\'s a language that has some of the same behavior as our language, but it has very different things that are needed for it to be a language.\n\nThis is the second way that we can say, "I want to write a language that does not have all of these things." The first way is to say, "I want to write a language that does have all of these things." The second way is to say "I want to write a language that has all of these things, but it has an entirely different way of doing them."\n\nThis is the first way of doing it. In other words,'}]

# %%
from transformers import GPT2Tokenizer, GPT2Model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-xl')
model = GPT2Model.from_pretrained('gpt2-xl')
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)

# %%
from transformers import GPT2Tokenizer, TFGPT2Model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-xl')
model = TFGPT2Model.from_pretrained('gpt2-xl')
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='tf')
output = model(encoded_input)
# Out:
# TensorFlow and JAX classes are deprecated and will be removed in Transformers v5. We recommend migrating to PyTorch classes or pinning your version of Transformers.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3165253775.py in <cell line: 0>()
#       1 from transformers import GPT2Tokenizer, TFGPT2Model
#       2 tokenizer = GPT2Tokenizer.from_pretrained('gpt2-xl')
# ----> 3 model = TFGPT2Model.from_pretrained('gpt2-xl')
#       4 text = "Replace me by any text you'd like."
#       5 encoded_input = tokenizer(text, return_tensors='tf')
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_tf_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2953                 model.build_in_name_scope()  # build the network with dummy inputs
#    2954         else:
# -> 2955             model.build_in_name_scope()  # build the network with dummy inputs
#    2956
#    2957         if safetensors_from_pt and not is_sharded:
#
# /usr/local/lib/python3.12/dist-packages/transformers/modeling_tf_utils.py in build_in_name_scope(self)
#    1175     def build_in_name_scope(self):
#    1176         with tf.name_scope(self.name):
# -> 1177             self.build(input_shape=None)
#    1178
#    1179     @property
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/gpt2/modeling_tf_gpt2.py in build(self, input_shape)
#     824         if getattr(self, "transformer", None) is not None:
#     825             with tf.name_scope(self.transformer.name):
# --> 826                 self.transformer.build(None)
#     827
#     828
#
# /usr/local/lib/python3.12/dist-packages/transformers/models/gpt2/modeling_tf_gpt2.py in build(self, input_shape)
#     564         if getattr(self, "wte", None) is not None:
#     565             with tf.name_scope(self.wte.name):
# --> 566                 self.wte.build(None)
#     567         if getattr(self, "wpe", None) is not None:
#     568             with tf.name_scope(self.wpe.name):
#
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/utils/tf_utils.py in wrapper(instance, input_shape)
#     369         if input_shape is not None:
#     370             input_shape = convert_shapes(input_shape, to_tuples=True)
# --> 371         output_shape = fn(instance, input_shape)
#     372         # Return shapes from `fn` as TensorShapes.
#     373         if output_shape is not None:
#
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/layers/core/embedding.py in build(self, input_shape)
#     178     @tf_utils.shape_type_conversion
#     179     def build(self, input_shape=None):
# --> 180         self.embeddings = self.add_weight(
#     181             shape=(self.input_dim, self.output_dim),
#     182             initializer=self.embeddings_initializer,
#
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, **kwargs)
#     703             getter = functools.partial(getter, layout=layout)
#     704
# --> 705         variable = self._add_variable_with_custom_getter(
#     706             name=name,
#     707             shape=shape,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/trackable/base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     490         # "best effort" to set the initializer with the highest restore UID.
#     491         initializer = checkpoint_initializer
# --> 492     new_variable = getter(
#     493         name=name,
#     494         shape=shape,
#
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/engine/base_layer_utils.py in make_variable(name, shape, dtype, initializer, trainable, caching_device, validate_shape, constraint, use_resource, collections, synchronization, aggregation, partitioner, layout, experimental_enable_variable_lifting)
#     135         # However, this breaks legacy (Estimator) checkpoints because
#     136         # it changes variable names. Remove this when V1 is fully deprecated.
# --> 137         return tf1.Variable(
#     138             initial_value=init_val,
#     139             name=name,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     196   def __call__(cls, *args, **kwargs):
#     197     if hasattr(cls, "_variable_call") and callable(cls._variable_call):
# --> 198       variable_call = cls._variable_call(*args, **kwargs)
#     199       if variable_call is not None:
#     200         return variable_call
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/variable_v1.py in _variable_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape, experimental_enable_variable_lifting, expected_shape, collections, use_resource, **kwargs)
#     305     if aggregation is None:
#     306       aggregation = variables.VariableAggregation.NONE
# --> 307     return previous_getter(
#     308         initial_value=initial_value,
#     309         trainable=trainable,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/variable_v1.py in <lambda>(**kwargs)
#     298     if cls is not VariableV1:
#     299       return None
# --> 300     previous_getter = lambda **kwargs: default_variable_creator(None, **kwargs)
#     301     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     302       previous_getter = variables._make_getter(getter, previous_getter)  # pylint: disable=protected-access
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/variable_v1.py in default_variable_creator(next_creator, **kwds)
#      44   from tensorflow.python.ops import ref_variable  # pylint: disable=g-import-not-at-top
#      45
# ---> 46   return ref_variable.default_variable_creator(
#      47       next_creator=next_creator, **kwds
#      48   )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/ref_variable.py in default_variable_creator(next_creator, **kwargs)
#      65   if use_resource:
#      66     distribute_strategy = kwargs.get("distribute_strategy", None)
# ---> 67     return resource_variable_ops.ResourceVariable(
#      68         initial_value=initial_value,
#      69         trainable=trainable,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/variables.py in __call__(cls, *args, **kwargs)
#     199       if variable_call is not None:
#     200         return variable_call
# --> 201     return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     202
#     203
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape, handle, experimental_enable_variable_lifting)
#    1874                              handle=handle)
#    1875     else:
# -> 1876       self._init_from_args(
#    1877           initial_value=initial_value,
#    1878           trainable=trainable,
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape, validate_shape, experimental_enable_variable_lifting)
#    2058           with ops.name_scope("Initializer"), device_context_manager(None):
#    2059             if init_from_fn:
# -> 2060               initial_value = initial_value()
#    2061             if isinstance(initial_value, trackable.CheckpointInitialValue):
#    2062               self._maybe_initialize_trackable()
#
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/initializers/initializers.py in __call__(self, shape, dtype, **kwargs)
#     523                 nonce,
#     524             )
# --> 525         return self._random_generator.truncated_normal(
#     526             shape, self.mean, self.stddev, dtype, nonce
#     527         )
#
# /usr/local/lib/python3.12/dist-packages/tf_keras/src/backend.py in truncated_normal(self, shape, mean, stddev, dtype, nonce)
#    2142             if nonce:
#    2143                 seed = tf.random.experimental.stateless_fold_in(seed, nonce)
# -> 2144             return tf.random.stateless_truncated_normal(
#    2145                 shape=shape, mean=mean, stddev=stddev, dtype=dtype, seed=seed
#    2146             )
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/stateless_random_ops.py in stateless_truncated_normal(shape, seed, mean, stddev, dtype, name, alg)
#     742         shape, key=key, counter=counter, dtype=dtype, alg=alg
#     743     )
# --> 744     result = math_ops.add(rnd * stddev, mean, name=name)
#     745     shape_util.maybe_set_static_shape(result, shape)
#     746     return result
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/weak_tensor_ops.py in wrapper(*args, **kwargs)
#     140   def wrapper(*args, **kwargs):
#     141     if not ops.is_auto_dtype_conversion_enabled():
# --> 142       return op(*args, **kwargs)
#     143     bound_arguments = signature.bind(*args, **kwargs)
#     144     bound_arguments.apply_defaults()
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/math_ops.py in add(x, y, name)
#    3959       return gen_math_ops.add(x, y, name=name)
#    3960     else:
# -> 3961       return gen_math_ops.add_v2(x, y, name=name)
#    3962
#    3963
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/gen_math_ops.py in add_v2(x, y, name)
#     475   if tld.is_eager:
#     476     try:
# --> 477       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#     478         _ctx, "AddV2", name, x, y)
#     479       return _result
#
# KeyboardInterrupt:

# %%
from transformers import pipeline, set_seed
generator = pipeline('text-generation', model='gpt2-xl')
set_seed(42)
generator("The man worked as a", max_length=10, num_return_sequences=5)

set_seed(42)
generator("The woman worked as a", max_length=10, num_return_sequences=5)
# Out:
# Device set to use cuda:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=10) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=10) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': "The woman worked as a clerk at a convenience store and had been living at a shelter for the homeless for about a month, the Tribune reported.\n\nThe woman told police she hadn't had any contact with the man in over two years.\n\nThe suspect, a white man, was wearing a white polo shirt, blue pants and a black baseball cap. He is about six feet tall and had a muscular build, authorities said.\n\nHe was last seen driving a silver Volkswagen Beetle."},
#  {'generated_text': 'The woman worked as a secretary at a local school in the town of Nijmegen in the Dutch province of Holland.\n\nShe told police that she had a "sexual relationship" with the student and that he was "too much of a coward" to stop her.\n\nThe student, a 24-year-old from Syria, had been studying for a master\'s degree in the same field.\n\nHe is now in custody.\n\n\'Not a criminal\'\n\nThe Dutch school is located in a residential area of the city.\n\nThe Dutch media reported that the woman\'s husband had been informed of the relationship.\n\nThe Dutch government has so far declined to comment on the case.\n\n"The woman is not a criminal, she is a victim," the defence ministry said in a statement on Wednesday.\n\n"The case will be examined carefully by the relevant authorities."\n\nThe case is the latest in a series of sexual assaults in schools across Europe.'},
#  {'generated_text': 'The woman worked as a cleaner, and a neighbour said she often came home smelling of alcohol.\n\nPolice arrested her and charged her with one count of dangerous driving causing injury.\n\nShe appeared at the Perth Magistrates Court on Monday, and was granted conditional bail to appear at the same court again on January 23.\n\nTopics: courts-and-trials, perth-6000, wa\n\nFirst posted'},
#  {'generated_text': 'The woman worked as a housekeeper for the former First Lady and daughter Elizabeth.\n\nClinton\'s campaign said she had been diagnosed with pneumonia on Friday, and a campaign aide said on Sunday that she was feeling "a little better."\n\nClinton\'s campaign did not respond to a request for comment at the time of publication.\n\nOn Monday, Clinton returned to the campaign trail and held a rally in Cleveland.'},
#  {'generated_text': "The woman worked as a schoolteacher in the city of Chongqing. She was visiting with her husband, a fellow teacher, whom she met in the city.\n\nAccording to the report, the two drove to a park near the couple's home in a car driven by the husband. The husband allegedly grabbed the woman by the arm and dragged her by the hair into the bushes.\n\nThe man then allegedly raped the woman.\n\nThe woman managed to escape the bushes and ran to a nearby shop, where she alerted the staff.\n\nThe police were called, and the husband was arrested. He is said to have confessed to the crime.\n\nAccording to the report, the husband is a Chinese national.\n\nChinese media has reported that Chinese police are now investigating the case."}]
